# %%
import sys
import re
import os
from docx import Document
import pandas as pd
from IPython.display import display, HTML

class CorpusProcessor:
    def __init__(self, path='.'):
        self.result = []
        self.path = path
        self._process_path(self.path)
        
    def regex_search(self, query_word):
        """
        query_word: <Str>
            要搜索的字串，此搜索字串會先丟入re.compile()
            因此可以接收regex string
            例如此參數可以輸入"(LOC|INS)"
            則可以給出所有標有LOC或INS的語料。
        """

        pattern = re.compile(query_word)
        r = self._query_keyword(pattern)
        self._display_as_dataframe(r)
    
                    
    def easy_search(self):
        result = {}
        
        print('請輸入想要搜尋的字串:')
        print('如果想搜尋多個字串，請在字串之間以逗號分隔，例如: "主格,i,媽媽"')
        print('如果想找的i為單獨出現的i，而非出現在某單詞中的i，請在i的兩邊加上空格')
        
        x = str(input("請輸入想要查找字詞："))
        
        query_words = [word for word in x.split(',')]
        
        if x=="e" or x=="E":
            return
        else:
            for file in self.result:
                result[file["file_name"]] = [sentence for sentence in file["data"] if all([re.search(re.compile(word), str(sentence)) for word in query_words])]
            
            self._display_as_dataframe(result)

    def search_note(self):
        result = {}
        
        print('請輸入想要搜尋#note當中的字串:')
        
        x = str(input("請輸入想要查找字詞："))
        
#         query_words = [word for word in x.split(',')]
        
        if x=="e" or x=="E":
            return
        else:
            for file in self.result:
                result[file["file_name"]] = []
                for sentence in file["data"]:
                    l = sentence['content'].split('#n')
                    if len(l) == 2 and re.search(re.compile(x), l[1]):
                        result[file["file_name"]].append(sentence)
            
            self._display_as_dataframe(result)

    def all_data(self):
        return self.result
            
    def _display_as_dataframe(self, r):
        for k, v in r.items():
            print(f"<< {k} >>")
            if len(v) == 0:
                print("本週無相關資料")
            else:
                for item in v:
                    n = item['num']
                    c = item['content']
                    cc = c.split('\n')
                    cc = list(filter(lambda x: x!='', cc))
                    display(pd.DataFrame([cc[0].split(), cc[1].split(), cc[2].split()]).rename({0: "泰雅：", 1: "英文：", 2: "中文："}, axis='index')) 
                    try:
                        print("[英文翻譯]")
                        print([ccc for ccc in cc if ccc.startswith("#e")][0])
                        print("[中文翻譯]")
                        print([ccc for ccc in cc if ccc.startswith("#c")][0])
                        print("[註釋]")
                        print([ccc for ccc in cc if ccc.startswith("#n")][0])
                    except:
                        pass
    
    def _process_path(self, p):
        for filename in os.listdir(p):
            if not filename.startswith("~") and (filename.endswith(".docx") or filename.endswith(".doc")):
                document = self._open_file(os.path.join(p, filename))
                self.result.append(self._process(document, filename))

    def _open_file(self, name):
        d = Document(name)
        return d
    
    
    def _process(self, doc, filename):
        result = {
            "file_name": filename,
            "data": []
        }
        all_p = doc.paragraphs
        num_re = re.compile("(\d{1,2})\.")

        num = 0
        current_index = -1
        # rrr = map(lambda x: re.match(num_re, x.text), all_p)
        start = False
        num_re = re.compile("(\d{1,2})\.")
        for p in all_p:
            match = re.match(num_re, p.text)

            if match:
                start = True
                num = match.group(1)
                result["data"].append({"num": num, "content": ""})
                current_index = len(result["data"]) - 1
            else:
                if not start:
                    pass
                else:
                    result["data"][current_index]["content"] += "\n" + p.text

        return result
    
    def _query_keyword(self, q):
        result = {}

        for file in self.result:
            result[file["file_name"]] = [sentence for sentence in file["data"] if re.search(q, sentence["content"])]

        return result

# %%
p = CorpusProcessor(path='./corp')
#c.search_note()
p.easy_search()
# Out:
# 請輸入想要搜尋的字串:
# 如果想搜尋多個字串，請在字串之間以逗號分隔，例如: "主格,i,媽媽"
# 如果想找的i為單獨出現的i，而非出現在某單詞中的i，請在i的兩邊加上空格
# 請輸入想要查找字詞： aaaaaaaaa
# << 20200325.docx >>
# 本週無相關資料
# << 20200408.docx >>
# 本週無相關資料
# << 20200325_n.docx >>
# 本週無相關資料
# << 20200318.docx >>
# 本週無相關資料

# %%
#result[file["file_name"]] = [sentence for sentence in file["data"] if all([re.search(re.compile(word), str(sentence)) for word in query_words])]
lines = p.result[0]['data'][0]['content'].strip().split('\n')

gloss_lines = lines[:-3]
free_lines = lines[-3:]

# Concat gloss lines to three lines

# %%
for doc_id, doc in enumerate(p.result):
    for gloss_id in range(len(doc)):
        lines = p.result[doc_id]['data'][gloss_id]['content'].strip().split('\n')
        gloss_lines = lines[:-3]
        free_lines = lines[-3:]

        # 3*n + n
        gloss_lines = lines[:-3]
        num_of_lines = len(gloss_lines) 

        if num_of_lines % 4 != 0:
            print(p.result[doc_id]['file_name'], doc_id, gloss_id)
            raise Exception("len(gloss_lines) should be multiples of 4.")

        # Concat multiple lines to three
        rk_gloss = ''
        en_gloss = ''
        zh_gloss = ''
        for i in range(int(num_of_lines / 4)):
            rk_gloss += gloss_lines[0 + i * 4] + '\t'
            en_gloss += gloss_lines[1 + i * 4] + '\t'
            zh_gloss += gloss_lines[2 + i * 4] + '\t'

        rk_gloss = rk_gloss.strip().split()
        en_gloss = en_gloss.strip().split()
        zh_gloss = zh_gloss.strip().split()

        # Tokenize
        gloss = []
        en_len = len(en_gloss)
        zh_len = len(zh_gloss)
        for i, rk in enumerate(rk_gloss):

            if not i < en_len:
                en = '_'
            else:
                en = en_gloss[i]
            if not i < zh_len:
                zh = '_'
            else:
                zh = zh_gloss[i]

            gloss.append( (rk, en, zh) )

        # Save data
        p.result[doc_id]['data'][gloss_id]['content_parsed'] = {
            'gloss': gloss,
            'free': free_lines
        }
# Out:
# 20200408.docx 1 0
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-bb218680c2ec> in <module>
#      11         if num_of_lines % 4 != 0:
#      12             print(p.result[doc_id]['file_name'], doc_id, gloss_id)
# ---> 13             raise Exception("len(gloss_lines) should be multiples of 4.")
#      14
#      15         # Concat multiple lines to three
#
# Exception: len(gloss_lines) should be multiples of 4.

# %%
#p.result[2]
d = Document("corp/20200325_n.docx")
d2 = Document("corp/20200325.docx")

process_doc("corp/20200408.docx")
# Out:
# [(1,
#   ['kay\t\tElrenge\t\ttakane',
#    'this\t\tElrenge\t\tolder_sister',
#    '這\t\tElrenge\t\t兄姐',
#    '',
#    '#e Is Elrenge my older sister?',
#    '#c Elrenge 是我的姊姊嗎？',
#    '#n Not sure about last word.']),
#  (2,
#   ['ngia-~ka~kane-aku\t\t\tki\t\taga',
#    'oneself-eat~ka~eat-1SG\t\tOBL\tmeal',
#    '自己-吃~ka~吃-我 \t\t\t斜格\t飯.餐',
#    '',
#    '#e I eat (a meal) myself.',
#    '#c 我自己用餐',
#    '#n']),
#  (3,
#   ['kay\tElrenge\tngia-u~dulri~dulri',
#    'this\tElrenge\toneself-跳舞~正在~跳舞',
#    '這\tElrenge\t自己-跳舞~PROG~跳舞',
#    ' ',
#    '#e Elrenge is dancing by herself',
#    '#c Elrenge 自己在跳舞']),
#  (4,
#   ['kay\tElrenge\tngia-udulri',
#    'this\tElrenge\tonself-dance',
#    '這\tElrenge\t自己-跳舞',
#    ' ',
#    '#e Elrenge dance alone (when alone).',
#    '#c Elrenge (會)自己跳舞',
#    '#n Contrast with 3 in tense']),
#  (5,
#   ['kay \tElrenge\tngia-drakale \t\tki\t\tpitu\t\tki\t\ttuki\t',
#    'this\tElrenge\toneself-get_up\t\tOBL\tseven\tOBL\tclock',
#    '這\tElrenge\t自己-起來 \t\t斜格\t七\t\t斜格\t時鐘',
#    '',
#    'luka\t\tmialrealre',
#    'at\t\tmorning',
#    '當.在\t早晨',
#    '',
#    '#e Elrenge woke up by herself at 7 o’clock in the morning.',
#    '#c Elrenge 在早上七點鐘自己起床']),
#  (6,
#   ['Kaku,\tni\t\tdrakale',
#    'Kaku,\tIMP\t\tget_up',
#    'Kaku,\t命令你\t起來',
#    '',
#    '#e Kaku, get up!',
#    '#c Kaku, (站)起來',
#    '#n  (祈使句) 命令 Kaku 起來']),
#  (7,
#   ['drakale\tki\t\tKaku',
#    'get_up\tOBL\tKaku',
#    '起來\t斜格\tKaku',
#    '',
#    '#e Get  Kaku up.',
#    '#c 給他(挖)起來',
#    '#n (Kaku 在睡覺，叫別人) 把 Kaku 挖起來']),
#  (8,
#   ['mialrealre,\tni\t\tdrakale',
#    'morning,\t\tIMP\t\tget_up',
#    '早晨\t\t命令你\t起來',
#    '',
#    '#e (It’s) morning, get/wake up.',
#    '#c 天亮了，起床了',
#    '#n ']),
#  (9,
#   ['kay\tElrenge\tngia-u~dulri~dulri',
#    'this\tElrenge\toneself-dance~PROG~dance',
#    '這\tElrenge\t自己-跳舞~正在~跳舞',
#    '',
#    '#e Elrenge is dancing by herself.',
#    '#c Elrenge 自己正在跳舞',
#    '#n 也可用 udulridulri，意義變成「會」(able to) 跳舞']),
#  (10,
#   ['kay\t\tElrenge\tluka\t\tvaivai \t\tngia-drakale\t\tki\t\tvalru',
#    'this\t\tElrenge\tat\t\tevery_day\toneself-get_up\t\tOBL\teight',
#    '這\t\tElrenge\t當.在\t每天\t\t自己-起來\t\t斜格\t八',
#    '',
#    'ki \t\ttuki\t\tluka\t\tmialrealre',
#    'OBL\tclock\tat\t\tmorning',
#    '斜格\t時鐘\t當.在\t早晨',
#    '',
#    '#e Elegnge wakes up every day at eight o’clock in the morning.',
#    '#c Elegnge 在每天(在)早上8點起床',
#    '#n valru: 8, 溪流(溪流像 8); vai：太陽 ; vaivai: 每天']),
#  (11,
#   ['kay\tbabila\tpa\t\ttubi\t\tki\t\tTakanaw',
#    'this\tmonkey\tCAU\tcry\t\tOBL\tTakanaw',
#    '這\t猴子\t使\t\t哭\t\t斜格\tTakanaw\t\t\t',
#    '',
#    '#e This monkey caused Takanaw to cry.',
#    '#c 這個猴子讓 Takanaw 哭了',
#    '#n']),
#  (12,
#   ['kay\tbabila\tpa\t\ttubi\t\tki\t\tTakanaw\t\tanikamani\tma-kiucu',
#    'this \tmonkey\tCAU\tcry\t\tOBL\tTakanaw\t\tbecause\t\tma-afraid',
#    '這\t猴子\t使\t\t哭\t\t斜格\tTakanaw\t\t因為.所以\tma-害怕',
#    '',
#    'kay\tTakanaw\t\tki\t\tbabila',
#    'this\tTakanaw\t\tOBL\tmonkey',
#    '這\tTakanaw\t\t斜格\t猴子',
#    '',
#    '#e This monkey caused Takanaw to cry because Takanaw is afraid of the monkey.',
#    '#c 猴子把Takanaw 嚇哭了，因為Takanaw 很怕猴子',
#    '#n 讀法：maki.u.cu。 anikamani?']),
#  (13,
#   ['ku\t\tama\t\t\tpa\t\tudulri\tki\t\tTakanaw',
#    'NOM\tmy_father\tCAU\tdance\tOBL\tTakanaw',
#    '主格\t我爸爸\t\t使\t\t跳舞\t斜格\tTakanaw',
#    '',
#    '#e My father caused Takanaw to dance.',
#    '#c 我爸爸讓 Takanaw 跳舞']),
#  (14,
#   ['pa\t\tka\t\tkiucu-su\t\tnakuane',
#    'CAU\tNOM\tafraid-2SG\t1SG',
#    '使\t\t主格\t害怕-你\t\t我',
#    '',
#    '#e You caused me to be scared.',
#    '#c 你讓我害怕',
#    '#n ']),
#  (15,
#   ['ma-kiuc-aku\t\tmusuane',
#    'ma-afraid-1SG\t\t2SG',
#    'ma-害怕-我\t\t你',
#    '',
#    '#e I’m afraid of you.',
#    '#c 我很怕你',
#    '#n kiucu 是詞根, ma-kiuc-aku 讀法：ma.kiu.ca.ku']),
#  (16,
#   ['kay\tElrenge\tlri-ni-drakale\t\tki\t\tbangate\tki\t\tduki\t\tluka\t',
#    'this\tElrenge\tFUT-ni-get_up\t\tOBL\tnine\t\tOBL\tclock\tat',
#    '這\tElrenge\t將要-ni-起來\t\t斜格\t九\t\t斜格\t時鐘\t當.在',
#    '',
#    'mialrealre\tlri-mu-lregelrege',
#    'morning\t\tFUT-go-mountain',
#    '早晨\t\t將要-去-山',
#    '',
#    '#e Elrenge will get up at 9 o’clock in the morning because she will go to the mountain.',
#    '#c Elrenge 早上 9 點要起床，因為要去山上',
#    '#n lri-mu-elregelrge 可放在最前面']),
#  (17,
#   ['luiya\t\t\tkay\t\tElrenge\tlri-ni-drakale\t\tki\t\tbangate',
#    'tomorrow\t\tthis\t\tElrenge\tFUT-ni-get_up\t\tOBL\tnine',
#    '明天\t\t這個\tElrenge\t將要-ni-起來\t\t斜格\t九',
#    '',
#    'ki \t\ttuki\t\tluka \t\tmialrealre\tlri-mu-lregelrege',
#    'OBL\tclock\tat\t\tmorning\t\tFUT-go-mountain',
#    '斜格\t時鐘\t當.在\t早晨\t\t將要-去-山',
#    '',
#    '#e Tomorrow, Elrenge will get up at nine o’clock in the morning because she will go to the mountain.',
#    '#c 明天 (這個) Elrenge (將要) 9 點起床，因為要去山上',
#    '#n']),
#  (18,
#   ['kay\tElrenge\tlri-ni-drakale\t\tki\t\tbangate\tki\t\ttuki\t\tluka\t',
#    'this\tElrenge\tFUT-ni-get_up\t\tOBL\tnine\t\tOBL\tclock\tat',
#    '這\tElrenge\t將要-ni-起來\t\t斜格\t九\t\t斜格\t時鐘\t當.在',
#    '',
#    'mialrealre\tlri-mu-lregelrege\tluiya',
#    'morning\t\tFUT-go-mountain\ttomorrow',
#    '早晨\t\t將要-去-山\t\t 明天',
#    '',
#    '#e Tomorrow, Elrenge will get up at nine o’clock in the morning because she will go to the mountain.',
#    '#c 明天 (這個) Elrenge (將要) 9 點起床，因為要去山上',
#    '#n上一句的詞序調換']),
#  (19,
#   ['lri-mu-lregelrege\tluiya\t\t\tkay\tElrenge\tlri-ni-drakale',
#    'FUT-go-mountain\ttomorrow\t\tthis\tElrenge\tFUT-ni-get_up',
#    '將要-去-山\t\t明天\t\t這\tElrenge\t將要-ni-起來',
#    '',
#    'ki\t\tbangate \tki \t\ttuki\t\tluka\t\tmialrealre',
#    'OBL\tnine\t\tOBL\tclock\tat\t\tmorning',
#    '斜格\t九\t\t斜格\t時鐘\t當.在\t早晨',
#    '',
#    '#e Tomorrow, Elrenge will get up at nine o’clock in the morning because she will go to the mountain.',
#    '#c 明天 (這個) Elrenge (將要) 9 點起床，因為要去山上',
#    '#n上一句的詞序調換']),
#  (20,
#   ['lri-mu-lregelrege\tkay\tElrenge\tluiya\t\t\tlri-ni-drakale',
#    'FUT-go-mountain\tthis\tElrenge\ttomorrow\t\tFUT-ni-get_up\t',
#    '將要-去-山\t\t這\tElrenge\t明天\t\t將要-ni-起來',
#    '',
#    'ki\t\tbangate \t\tki\t\ttuki\t\tluka\t\tmialrealre',
#    'OBL\tnine\t\t\tOBL\tclock\tat\t\tmorning',
#    '斜格\t九\t\t\t斜格\t時鐘\t當.在\t早晨',
#    '',
#    '#e Tomorrow, Elrenge will get up at nine o’clock in the morning because she will go to the mountain.',
#    '#c 明天 (這個) Elrenge (將要) 9 點起床，因為要去山上',
#    '#n上一句的詞序調換']),
#  (21,
#   ['maka-dalame-nay\t\tki \t\tElrenge\tlay\t\tlri-karudrange-nay',
#    'each_other-love-1PL\tOBL\tElrenge\tso\t\tFUT\t-marry-1PL',
#    '互相-愛-我們\t\t\t斜格\tElrenge\t所以\t未來-結婚-我們',
#    ' ',
#    '#e I and Elrenge love each other so we will get married.',
#    '#c 我跟 Elrenge 很相愛，所以我們未來會結婚',
#    '#n rudrange 耆老.長輩.成熟 (50歲up)']),
#  (22,
#   ['aisi\t\t\t(lu)\t\t\tmaka-dalame-nai\t\tki\t \tElrenge',
#    'COND.if\t\tCOND.if\t\teach_other-love-1PL\tOBL\tElrenge',
#    '如果\t\t如果\t\t相-愛-我們\t\t\t斜格\tElrenge',
#    '',
#    'lri-karudrange-nay',
#    'FUT\t-marry-1PL',
#    '未來-結婚-我們',
#    '',
#    '#e If I and Elrenge love each other, we will get married.',
#    '#c 如果我跟 Elrenge 很相愛，我們未來會結婚',
#    '#n aisi, lu 可以單用：aisi maka-... or lu maka-...'])]

# %%
def process_doc(fp="corp/20200325.docx"):
    
    # Load document
    d = Document(fp)
    a_doc = '\n'.join(p.text for p in d.paragraphs)  # normalize paragraphs to newlines
    
    # Find the places of glosses
    pat_start = re.compile("^(\d{1,2})\.")
    a_doc_split = a_doc.split('\n')
    glosses_on = []
    gloss_num_old = None
    for i, line in enumerate(a_doc_split):

        if pat_start.match(line):
            gloss_num_new = i

            # Save gloss range
            if gloss_num_old is not None:
                glosses_on.append( (gloss_num_old, gloss_num_new - 1) )
            gloss_num_old = gloss_num_new

    # Get all glosses
    glosses = []
    for s, e in glosses_on:
        gloss_num = int(a_doc_split[s][:-1])
        gloss_lines = a_doc_split[(s+1):e]
        glosses.append( (gloss_num, gloss_lines) )
    
    return glosses

# %%
glosses
# Out:
# [(1,
#   ['yakay\tku\ttatulru\t(ku\tababay/sauvalay)\tku',
#    'have\t\t\tthree\t\tfemale/male',
#    '有\t\t\t3\t\t女性/男性\t\t\t\t',
#    '\t\t',
#    'agi-li',
#    'yonger_brother/sister-1SG.POSS',
#    '弟妹-我的.第一人稱單數.所有格',
#    '',
#    '#e I have 3 younger brother/sister',
#    '#c 我有 3 個弟弟/妹妹',
#    '#n  yakay\tku 可省略']),
#  (2,
#   ['ka\t\tLaucu\ttakalra\tku\t\tla-taka-ini',
#    'NOM\tLaucu\tmany\tOBL\tPL-older_brother/sister-3SG.POSS',
#    '主格\tLaucu\t很多\t斜格\t複數-兄姐-他的.第三人稱單數.所有格',
#    '',
#    '#e Laucu has many older brothers/sisters',
#    '#c Laucu 有很多兄姐',
#    '#n ta-kalra, ta: 比「多」更多的意思, kalra: 「多」。人名放在前面不可用 ki 標記。']),
#  (3,
#   ['ka\t\tLaucu\tkadrua\tku\t\tababay\tku\t',
#    'NOM\tLaucu\tNEG\tOBL\tfemale\tOBL',
#    '主格\tLaucu\t沒有\t斜格\t女性\t斜格',
#    '',
#    'taka-ini',
#    'older_brother/sister-3SG.POSS',
#    '兄姐-他的.第三人稱單數.所有格',
#    '',
#    '#e Laucu has no older sister.',
#    '#c Laucu\t沒有姊姊。',
#    '#n']),
#  (4,
#   ['kadrua\tku\t\tababay\tku\t\tagi',
#    'NEG\tOBL\tfemale\tOBL\tyonger_brother/sister',
#    '沒有\t斜格\tfemale\t斜格\tyonger_brother/sister',
#    '',
#    '#e Don’t you have a younger sister',
#    '#c (你)沒有妹妹嗎？',
#    '#n 不禮貌']),
#  (5,
#   ['sinsi\t\t\tLegeane\tkadrua\tku\t\tababya\tku',
#    'Mr./Ms.\t\tLegeane\tNEG\tOBL\tfemale\tOBL',
#    '先生(尊稱)\tLegeane\t沒有\t斜格\t女\t\t斜格',
#    '',
#    'agi',
#    'younger_brother/sister',
#    '弟妹',
#    '',
#    '#e Legeane, don’t you have a sister?',
#    '#c Legeane, (你) 沒有妹妹嗎？',
#    '#n sinsi 尊稱']),
#  (6,
#   ['sinsi\t\t\tLegeane\tkadrua\tku\t\tagi\t\t\t\t\tku',
#    'Mr./Ms.\t\tLegeane\tNEG\tOBL\tyounger_brother/sister\tOBL',
#    '先生(尊稱)\tLegeane\t沒有\t斜格\t弟妹\t\t\t\t斜格',
#    '',
#    'ababya?',
#    'female',
#    '女',
#    '',
#    '#e Legeane, don’t you have a sister?',
#    '#c Legeane, (你) 沒有妹妹嗎？',
#    '#n 同上一句']),
#  (7,
#   ['ka\t\tLabausu\ttaka\t\t\t\t\tli',
#    'NOM\tLabausu\tolder_brother/sister\t\t1SG.POSS',
#    '主格\tLabausu\t兄姐\t\t\t\t我的.第一人稱單數.所有格',
#    '',
#    '#e Labausu is my older sister.',
#    '#c Labausu是我的姐姐',
#    '#n Labausu 是女名，所以不須額外表示 taka 的性別']),
#  (8,
#   ['taka-su\t\t\t\t\t\t\tki \t\tElrenge ?',
#    'older brother/sister-2SG.POSS\t\tOBL\tElrenge',
#    '兄姊-你的.第二人稱單數.所有格 \t斜格\tElrenge',
#    '',
#    '#e Is your sister Elrenge?',
#    '#c 你的姊姊是 Elrenge ？',
#    '#n Elrenge 是女名，所以不須額外表示 taka 的性別']),
#  (9,
#   ['ka\t\tElrenge\tw-a-udulri-nga',
#    'NOM\tElrenge\tAF-RLS-dance-CMPL',
#    '主格\tElrenge\t主焦-有-跳舞-已經',
#    '',
#    '#e Elrenge already started dancing.',
#    '#c Elrenge 已經在跳舞了。',
#    '#n']),
#  (10,
#   ['w-a-udulri-nga\t\t\t\tka\t\tElrenge',
#    'AF-RLS-dance-CMPL\t\tNOM\tElrenge',
#    '主焦-有-跳舞-已經\t\t\t主格\tElrenge',
#    '',
#    '#e Elrenge already started dancing.',
#    '#c Elrenge 已經在跳舞了。',
#    '#n 上一句的調換詞序']),
#  (11,
#   ['ka\tElrenge\tmaka\tw-a-udulri-nga',
#    'ka\tElrenge\tfinished\tAF-RLS-dance-CMPL\t',
#    'ka\tElrenge\t完成\t主焦-有-跳舞-已經',
#    '',
#    '#e Elrenge has finished dancing.',
#    '#c Elrenge 已經跳完舞了(休息了)',
#    '#n']),
#  (12,
#   ['Kui\tkadrwa',
#    'Kui\tabsent',
#    'Kui\t沒有.不見',
#    '',
#    '#e Kui disappear.',
#    '#c Kui 不見了',
#    '#n']),
#  (13,
#   ['ka\t\tKui\t\tmaduase',
#    'NOM\tKui\t\tleave',
#    '主格\tKui\t\t離開',
#    '',
#    '#e Kui left',
#    '#c Kui 離開了',
#    '#n 還看得到背影']),
#  (14,
#   ['ku\t\tKui\tmaduase-nga',
#    'NOM\tKui\tleave-CMPL',
#    '主格\tKui\t離開-已經',
#    '',
#    '#e Kui has left.',
#    '#c Kui 已經離開了',
#    '#n Kui 不在視線範圍內。*Ku\tKui\twa-maduase-nga']),
#  (15,
#   ['maduase-nga\t\tku\t\tKui',
#    'leave-CMPL\t\tNOM\tKui',
#    '離開-已經\t\t主格\tKui',
#    '',
#    '#e Kui has left.',
#    '#c Kui 已經離開了',
#    '#n 上一句的詞序調換']),
#  (16,
#   ['ma-buruku\t\t\tka\t\tdaane',
#    'entire-collapsed\t\tNOM\thouse',
#    '整個-塌了.碎了\t\t主格\t房子',
#    '',
#    '#e The house collapsed.',
#    '#c 房子塌了。',
#    '#n']),
#  (17,
#   ['ka\t\tdaane\tma-buruku',
#    'NOM\thouse\tentire-collapsed',
#    '主格\t房子\t整個-塌了.碎了',
#    '',
#    '#e The house collapsed.',
#    '#c 房子塌了。',
#    '#n 上一句詞序調換。*wa-ma-buruku']),
#  (18,
#   ['w-a-buru~buru~ku\t\t\t\t\t\tka\t\tdaane\tka\t\tLavurase',
#    'AF-RLS-demolish~PROG~ demolish\t\tOBL\thouse\tNOM\tLavurase',
#    '主焦-有-拆~正在~拆\t\t\t\t\t斜格\t房子\t主格\tLavurase',
#    '',
#    '#e Lavurase is demolishing the house.',
#    '#c Lavurase 正在拆房子。',
#    '#n ']),
#  (19,
#   ['ka\t\tLavurase\t\tw-a-buru~buru~ku\t\t\t\t\t\tka\t\tdaane',
#    'NOM\tLavurase\t\tAF-RLS-demolish~PROG~ demolish\t\tOBL\thouse',
#    '主格\tLavurase\t\t主焦-有-拆~正在~拆\t\t\t\t\t斜格\t房子',
#    '',
#    '#e Lavurase is demolishing the house.',
#    '#c Lavurase 正在拆房子。',
#    '#n 上一句的詞序調換。']),
#  (20,
#   ['w-a-buru~buru~ku\t\t\t\t\t\tka\t\tLavurase \t\tka\t\tdaane',
#    'AF-RLS-demolish~PROG~ demolish\t\tNOM\tLavurase\t\tOBL\thouse',
#    '主焦-有-拆~正在~拆\t\t\t\t\t主格\tLavurase\t\t斜格\t房子',
#    '',
#    '#e Lavurase is demolishing the house.',
#    '#c Lavurase 正在拆房子。',
#    '#n 上一句的詞序調換。']),
#  (21,
#   ['w-a-buruku\t\t\tka\t\tLavurase\t\tka\t\tdaane',
#    'AF-RLS-demolish\t\tNOM\tLavurase\t\tOBL\thouse',
#    '主焦-有-拆\t\t\t主格\tLavurase\t\t斜格\t房子',
#    '',
#    '#e Lavurase demolish the house.',
#    '#c Lavurase 有拆房子',
#    '#n 根據族語老師，wa-，表示「有」 (類似 realis 標記)']),
#  (22,
#   ['mathralili\t\tka\t\tpalrata',
#    'beautiful\t\tNOM\tBaibu_snake',
#    '漂亮\t\t主格\t百步蛇',
#    '',
#    '#e The Baibu snake is beautiful.',
#    '#c 百步蛇很漂亮。',
#    '#n']),
#  (23,
#   ['ka\t\tpalrata\t\tmathralili\t',
#    'NOM \tbeautiful\t\tBaibu_snake',
#    '主格 \t漂亮\t\t百步蛇',
#    '',
#    '#e The Baibu snake is beautiful.',
#    '#c 百步蛇很漂亮',
#    '#n 上一句的詞序調換']),
#  (24,
#   ['mathralili\t\tka\t\tTanebage',
#    'beautiful\t\tNOM\tTanebage',
#    '好.漂亮\t\t主格\tTanebage',
#    '',
#    '#e  ‘Tanebage is a good guy.’ Or, ‘Tanabage is handsome.’',
#    '#c Tanebage是個好人/很帥的人。',
#    '#n ']),
#  (25,
#   ['ka\t\tTanebage\t\tmathralili\t\tka',
#    'NOM\tTanebage\t\tbeautiful\t\tOBL',
#    '主格\tTanebage\t\t好.漂亮\t\t斜格',
#    '',
#    'tacebeane-ine',
#    'appearance-3SG.POSS',
#    '身材.外貌-他的.第三人稱單數.所有格',
#    '',
#    '#e Tanebage has a good appearance.',
#    '#c Tanebage的長相很好看',
#    '#n']),
#  (26,
#   ['mathralili\t\tkay\takaneane',
#    'beautiful\t\tthis\tfood',
#    '好.漂亮\t\t這\t食物',
#    '',
#    '#e This food is tasty.',
#    '#c 這食物很好吃',
#    '#n']),
#  (27,
#   ['tua\t\tthralili\t\tki \t\tkinaumasane\tkay\t \takaneane',
#    'CAU\tgood\t\tOBL\tbody\t\tthis\t\tfood',
#    '使\t\t好.漂亮\t\t斜格\t身體\t\t這\t\t食物',
#    '',
#    '#e This food is healthy (lit: This food is good for body)',
#    '#c 這食物對身體很好 (lit: 這食物使身體好)',
#    '#n'])]

# %%
# Out:
# ['1.', 'yakay\tku\ttatulru\t(ku\tababay/sauvalay)\tku', 'have\t\t\tthree\t\tfemale/male', '有\t\t\t3\t\t女性/男性\t\t\t\t', '\t\t', 'agi-li', 'yonger_brother/sister-1SG.POSS', '弟妹-我的.第一人稱單數.所有格', '', '#e I have 3 younger brother/sister', '#c 我有 3 個弟弟/妹妹', '#n  yakay\tku 可省略']
# ['2.', 'ka\t\tLaucu\ttakalra\tku\t\tla-taka-ini', 'NOM\tLaucu\tmany\tOBL\tPL-older_brother/sister-3SG.POSS', '主格\tLaucu\t很多\t斜格\t複數-兄姐-他的.第三人稱單數.所有格', '', '#e Laucu has many older brothers/sisters', '#c Laucu 有很多兄姐', '#n ta-kalra, ta: 比「多」更多的意思, kalra: 「多」。人名放在前面不可用 ki 標記。']
# ['3.', 'ka\t\tLaucu\tkadrua\tku\t\tababay\tku\t', 'NOM\tLaucu\tNEG\tOBL\tfemale\tOBL', '主格\tLaucu\t沒有\t斜格\t女性\t斜格', '', 'taka-ini', 'older_brother/sister-3SG.POSS', '兄姐-他的.第三人稱單數.所有格', '', '#e Laucu has no older sister.', '#c Laucu\t沒有姊姊。', '#n']
# ['4.', 'kadrua\tku\t\tababay\tku\t\tagi', 'NEG\tOBL\tfemale\tOBL\tyonger_brother/sister', '沒有\t斜格\tfemale\t斜格\tyonger_brother/sister', '', '#e Don’t you have a younger sister', '#c (你)沒有妹妹嗎？', '#n 不禮貌']
# ['5.', 'sinsi\t\t\tLegeane\tkadrua\tku\t\tababya\tku', 'Mr./Ms.\t\tLegeane\tNEG\tOBL\tfemale\tOBL', '先生(尊稱)\tLegeane\t沒有\t斜格\t女\t\t斜格', '', 'agi', 'younger_brother/sister', '弟妹', '', '#e Legeane, don’t you have a sister?', '#c Legeane, (你) 沒有妹妹嗎？', '#n sinsi 尊稱']
# ['6.', 'sinsi\t\t\tLegeane\tkadrua\tku\t\tagi\t\t\t\t\tku', 'Mr./Ms.\t\tLegeane\tNEG\tOBL\tyounger_brother/sister\tOBL', '先生(尊稱)\tLegeane\t沒有\t斜格\t弟妹\t\t\t\t斜格', '', 'ababya?', 'female', '女', '', '#e Legeane, don’t you have a sister?', '#c Legeane, (你) 沒有妹妹嗎？', '#n 同上一句']
# ['7.', 'ka\t\tLabausu\ttaka\t\t\t\t\tli', 'NOM\tLabausu\tolder_brother/sister\t\t1SG.POSS', '主格\tLabausu\t兄姐\t\t\t\t我的.第一人稱單數.所有格', '', '#e Labausu is my older sister.', '#c Labausu是我的姐姐', '#n Labausu 是女名，所以不須額外表示 taka 的性別']
# ['8.', 'taka-su\t\t\t\t\t\t\tki \t\tElrenge ?', 'older brother/sister-2SG.POSS\t\tOBL\tElrenge', '兄姊-你的.第二人稱單數.所有格 \t斜格\tElrenge', '', '#e Is your sister Elrenge?', '#c 你的姊姊是 Elrenge ？', '#n Elrenge 是女名，所以不須額外表示 taka 的性別']
# ['9.', 'ka\t\tElrenge\tw-a-udulri-nga', 'NOM\tElrenge\tAF-RLS-dance-CMPL', '主格\tElrenge\t主焦-有-跳舞-已經', '', '#e Elrenge already started dancing.', '#c Elrenge 已經在跳舞了。', '#n']
# ['10.', 'w-a-udulri-nga\t\t\t\tka\t\tElrenge', 'AF-RLS-dance-CMPL\t\tNOM\tElrenge', '主焦-有-跳舞-已經\t\t\t主格\tElrenge', '', '#e Elrenge already started dancing.', '#c Elrenge 已經在跳舞了。', '#n 上一句的調換詞序']
# ['11.', 'ka\tElrenge\tmaka\tw-a-udulri-nga', 'ka\tElrenge\tfinished\tAF-RLS-dance-CMPL\t', 'ka\tElrenge\t完成\t主焦-有-跳舞-已經', '', '#e Elrenge has finished dancing.', '#c Elrenge 已經跳完舞了(休息了)', '#n']
# ['12.', 'Kui\tkadrwa', 'Kui\tabsent', 'Kui\t沒有.不見', '', '#e Kui disappear.', '#c Kui 不見了', '#n']
# ['13.', 'ka\t\tKui\t\tmaduase', 'NOM\tKui\t\tleave', '主格\tKui\t\t離開', '', '#e Kui left', '#c Kui 離開了', '#n 還看得到背影']
# ['14.', 'ku\t\tKui\tmaduase-nga', 'NOM\tKui\tleave-CMPL', '主格\tKui\t離開-已經', '', '#e Kui has left.', '#c Kui 已經離開了', '#n Kui 不在視線範圍內。*Ku\tKui\twa-maduase-nga']
# ['15.', 'maduase-nga\t\tku\t\tKui', 'leave-CMPL\t\tNOM\tKui', '離開-已經\t\t主格\tKui', '', '#e Kui has left.', '#c Kui 已經離開了', '#n 上一句的詞序調換']
# ['16.', 'ma-buruku\t\t\tka\t\tdaane', 'entire-collapsed\t\tNOM\thouse', '整個-塌了.碎了\t\t主格\t房子', '', '#e The house collapsed.', '#c 房子塌了。', '#n']
# ['17.', 'ka\t\tdaane\tma-buruku', 'NOM\thouse\tentire-collapsed', '主格\t房子\t整個-塌了.碎了', '', '#e The house collapsed.', '#c 房子塌了。', '#n 上一句詞序調換。*wa-ma-buruku']
# ['18.', 'w-a-buru~buru~ku\t\t\t\t\t\tka\t\tdaane\tka\t\tLavurase', 'AF-RLS-demolish~PROG~ demolish\t\tOBL\thouse\tNOM\tLavurase', '主焦-有-拆~正在~拆\t\t\t\t\t斜格\t房子\t主格\tLavurase', '', '#e Lavurase is demolishing the house.', '#c Lavurase 正在拆房子。', '#n ']
# ['19.', 'ka\t\tLavurase\t\tw-a-buru~buru~ku\t\t\t\t\t\tka\t\tdaane', 'NOM\tLavurase\t\tAF-RLS-demolish~PROG~ demolish\t\tOBL\thouse', '主格\tLavurase\t\t主焦-有-拆~正在~拆\t\t\t\t\t斜格\t房子', '', '#e Lavurase is demolishing the house.', '#c Lavurase 正在拆房子。', '#n 上一句的詞序調換。']
# ['20.', 'w-a-buru~buru~ku\t\t\t\t\t\tka\t\tLavurase \t\tka\t\tdaane', 'AF-RLS-demolish~PROG~ demolish\t\tNOM\tLavurase\t\tOBL\thouse', '主焦-有-拆~正在~拆\t\t\t\t\t主格\tLavurase\t\t斜格\t房子', '', '#e Lavurase is demolishing the house.', '#c Lavurase 正在拆房子。', '#n 上一句的詞序調換。']
# ['21.', 'w-a-buruku\t\t\tka\t\tLavurase\t\tka\t\tdaane', 'AF-RLS-demolish\t\tNOM\tLavurase\t\tOBL\thouse', '主焦-有-拆\t\t\t主格\tLavurase\t\t斜格\t房子', '', '#e Lavurase demolish the house.', '#c Lavurase 有拆房子', '#n 根據族語老師，wa-，表示「有」 (類似 realis 標記)']
# ['22.', 'mathralili\t\tka\t\tpalrata', 'beautiful\t\tNOM\tBaibu_snake', '漂亮\t\t主格\t百步蛇', '', '#e The Baibu snake is beautiful.', '#c 百步蛇很漂亮。', '#n']
# ['23.', 'ka\t\tpalrata\t\tmathralili\t', 'NOM \tbeautiful\t\tBaibu_snake', '主格 \t漂亮\t\t百步蛇', '', '#e The Baibu snake is beautiful.', '#c 百步蛇很漂亮', '#n 上一句的詞序調換']
# ['24.', 'mathralili\t\tka\t\tTanebage', 'beautiful\t\tNOM\tTanebage', '好.漂亮\t\t主格\tTanebage', '', '#e  ‘Tanebage is a good guy.’ Or, ‘Tanabage is handsome.’', '#c Tanebage是個好人/很帥的人。', '#n ']
# ['25.', 'ka\t\tTanebage\t\tmathralili\t\tka', 'NOM\tTanebage\t\tbeautiful\t\tOBL', '主格\tTanebage\t\t好.漂亮\t\t斜格', '', 'tacebeane-ine', 'appearance-3SG.POSS', '身材.外貌-他的.第三人稱單數.所有格', '', '#e Tanebage has a good appearance.', '#c Tanebage的長相很好看', '#n']
# ['26.', 'mathralili\t\tkay\takaneane', 'beautiful\t\tthis\tfood', '好.漂亮\t\t這\t食物', '', '#e This food is tasty.', '#c 這食物很好吃', '#n']
# ['27.', 'tua\t\tthralili\t\tki \t\tkinaumasane\tkay\t \takaneane', 'CAU\tgood\t\tOBL\tbody\t\tthis\t\tfood', '使\t\t好.漂亮\t\t斜格\t身體\t\t這\t\t食物', '', '#e This food is healthy (lit: This food is good for body)', '#c 這食物對身體很好 (lit: 這食物使身體好)', '#n']

# %%
pat_start = re.compile("^(\d{1,2})\.")
x = pat_start.match("1.")

# %%
x[1]
# Out:
# '1'

# %%
gloss
# Out:
# [('yakay', 'have', '有'),
#  ('ku', 'three', '3'),
#  ('tatulru', 'female/male', '女性/男性'),
#  ('(ku', 'yonger_brother/sister-1SG.POSS', '弟妹-我的.第一人稱單數.所有格'),
#  ('ababay/sauvalay)', '_', '_'),
#  ('ku', '_', '_'),
#  ('agi-li', '_', '_')]

# %%
len(p.result[0]['data'])
# Out:
# 28

# %% [markdown]
# ## 使用說明

# %% [markdown]
# ### STEP 1: 先實例化`CorpusProcessor`物件
#
# ```
# p = CorpusProcessor()
# ```
#
# 也可以指名`.docx`檔所在路徑:
#
# ```
# p = CorpusProcesesor(path="<檔案所在路徑>")
# ```
#
# 若不指定path，則預設為與此`.ipynb`檔相同路徑
#
# ### STEP 2-1: 簡單搜尋
#
# 直接呼叫`easy_search()`方法，會跳出輸入框
#
# ```
# p.easy_search()
# ```
#
# ### STEP 2-2: 或者你也可以使用regular expression進行搜尋
#
# ```
# p.regex_search(regex)
# ```
#
# 此方法接收一個regex的字串參數，此字串會先丟入`re.compile()`當中
